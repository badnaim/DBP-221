# %%
import pandas as pd

# %%
dataset = pd.read_excel("Week7_Store_Data_Sample.xlsx")
dataset
# Out:
#           Order ID Order Date Customer ID      Segment     Region  \
# 0   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 1   CA-2016-152156 2016-11-08    EB-13930     Хувь хүн   Баянзүрх
# 2   CA-2016-138688 2016-06-12    MO-17950  Байгууллага    Хан-Уул
# 3   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# 4   US-2015-108966 2015-10-11    JO-15550     Хувь хүн   Баянзүрх
# ..             ...        ...         ...          ...        ...
# 95  US-2017-109484 2017-11-06    JR-15700       Гишүүн    Хан-Уул
# 96  CA-2017-161018 2017-11-09    AJ-10945       Гишүүн  Сүхбаатар
# 97  CA-2017-157833 2017-06-17    BM-11575     Хувь хүн    Хан-Уул
# 98  CA-2016-149223 2016-09-06    CV-12805  Байгууллага  Чингэлтэй
# 99  CA-2016-158568 2016-08-29    DK-12835       Гишүүн  Чингэлтэй
#
#                            Category             Product Name  Price  Quantity  \
# 0                    Чихэр, печенье       Shokolinsen 250 гр   3300         2
# ...

# %%
order_id = dataset['Order ID'].values
order_date = dataset['Order Date'].values
customer_id = dataset['Customer ID'].values
segment = dataset['Segment'].values
region = dataset['Region'].values
category = dataset['Category'].values
product_name = dataset['Product Name'].values
price = dataset['Price'].values
quantity = dataset['Quantity'].values
discount = dataset['Discount'].values
sales = dataset['Sales'].values

order_id_series = pd.Series(order_id)
order_date_series = pd.Series(order_date)
customer_id_series = pd.Series(customer_id)
segment_series = pd.Series(segment)
region_series = pd.Series(region)
category_series = pd.Series(category)
product_name_series = pd.Series(product_name)
price_series = pd.Series(price)
quantity_series = pd.Series(quantity)
discount_series = pd.Series(discount)
sales_series =pd.Series(sales)

# data = {
#     'Order ID'
# }

dataset1 = pd.DataFrame({'Order ID': order_id_series, 'Order Date': order_date_series, 'Customer ID': customer_id, 'Segment':segment, 'Region':region, 'Category': category, 'Product Name', 'Price', 'Quantity', 'Discount'})
# Out:
# 0     CA-2016-152156
# 1     CA-2016-152156
# 2     CA-2016-138688
# 3     US-2015-108966
# 4     US-2015-108966
#            ...
# 95    US-2017-109484
# 96    CA-2017-161018
# 97    CA-2017-157833
# 98    CA-2016-149223
# 99    CA-2016-158568
# Length: 100, dtype: object
