# %%
import numpy as np
import pandas as pd

#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]
Sdict = {"2005":0,"2006":1,"2007":2,"2008":3,"2009":4,"2010":5,"2011":6,"2012":7,"2013":8,"2014":9}

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]
Pdict = {"KobeBryant":0,"JoeJohnson":1,"LeBronJames":2,"CarmeloAnthony":3,"DwightHoward":4,"ChrisBosh":5,"ChrisPaul":6,"KevinDurant":7,"DerrickRose":8,"DwayneWade":9}

#Salaries
KobeBryant_Salary = [15946875,17718750,19490625,21262500,23034375,24806250,25244493,27849149,30453805,23500000]
JoeJohnson_Salary = [12000000,12744189,13488377,14232567,14976754,16324500,18038573,19752645,21466718,23180790]
LeBronJames_Salary = [4621800,5828090,13041250,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
CarmeloAnthony_Salary = [3713640,4694041,13041250,14410581,15779912,17149243,18518574,19450000,22407474,22458000]
DwightHoward_Salary = [4493160,4806720,6061274,13758000,15202590,16647180,18091770,19536360,20513178,21436271]
ChrisBosh_Salary = [3348000,4235220,12455000,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
ChrisPaul_Salary = [3144240,3380160,3615960,4574189,13520500,14940153,16359805,17779458,18668431,20068563]
KevinDurant_Salary = [0,0,4171200,4484040,4796880,6053663,15506632,16669630,17832627,18995624]
DerrickRose_Salary = [0,0,0,4822800,5184480,5546160,6993708,16402500,17632688,18862875]
DwayneWade_Salary = [3031920,3841443,13041250,14410581,15779912,14200000,15691000,17182000,18673000,15000000]
#Matrix
Salary = np.array([KobeBryant_Salary, JoeJohnson_Salary, LeBronJames_Salary, CarmeloAnthony_Salary, DwightHoward_Salary, ChrisBosh_Salary, ChrisPaul_Salary, KevinDurant_Salary, DerrickRose_Salary, DwayneWade_Salary])
# print("salary")

data1 = {'KobeBryant': KobeBryant_Salary,
        'JoeJohnson': JoeJohnson_Salary,
        'LeBronJames': LeBronJames_Salary,
        'CarmeloAnthony': CarmeloAnthony_Salary,
        'DwightHoward': DwightHoward_Salary,
        'ChrisBosh': ChrisBosh_Salary,
        'ChrisPaul': ChrisPaul_Salary,
        'KevinDurant': KevinDurant_Salary,
        'DerrickRose': DerrickRose_Salary,
        'DwayneWade': DwayneWade_Salary}
salary = pd.Series(data1)
# print(salary)

#Games 
KobeBryant_G = [80,77,82,82,73,82,58,78,6,35]
JoeJohnson_G = [82,57,82,79,76,72,60,72,79,80]
LeBronJames_G = [79,78,75,81,76,79,62,76,77,69]
CarmeloAnthony_G = [80,65,77,66,69,77,55,67,77,40]
DwightHoward_G = [82,82,82,79,82,78,54,76,71,41]
ChrisBosh_G = [70,69,67,77,70,77,57,74,79,44]
ChrisPaul_G = [78,64,80,78,45,80,60,70,62,82]
KevinDurant_G = [35,35,80,74,82,78,66,81,81,27]
DerrickRose_G = [40,40,40,81,78,81,39,0,10,51]
DwayneWade_G = [75,51,51,79,77,76,49,69,54,62]
#Matrix
Games = np.array([KobeBryant_G, JoeJohnson_G, LeBronJames_G, CarmeloAnthony_G, DwightHoward_G, ChrisBosh_G, ChrisPaul_G, KevinDurant_G, DerrickRose_G, DwayneWade_G])
print("games")
data2 = {'KobeBryant': KobeBryant_G,
        'JoeJohnson': JoeJohnson_G,
        'LeBronJames': LeBronJames_G,
        'CarmeloAnthony': CarmeloAnthony_G,
        'DwightHoward': DwightHoward_G,
        'ChrisBosh': ChrisBosh_G,
        'ChrisPaul': ChrisPaul_G,
        'KevinDurant': KevinDurant_G,
        'DerrickRose': DerrickRose_G,
        'DwayneWade': DwayneWade_G}
games = pd.Series(data2)
# print(games)

#Minutes Played
KobeBryant_MP = [3277,3140,3192,2960,2835,2779,2232,3013,177,1207]
JoeJohnson_MP = [3340,2359,3343,3124,2886,2554,2127,2642,2575,2791]
LeBronJames_MP = [3361,3190,3027,3054,2966,3063,2326,2877,2902,2493]
CarmeloAnthony_MP = [2941,2486,2806,2277,2634,2751,1876,2482,2982,1428]
DwightHoward_MP = [3021,3023,3088,2821,2843,2935,2070,2722,2396,1223]
ChrisBosh_MP = [2751,2658,2425,2928,2526,2795,2007,2454,2531,1556]
ChrisPaul_MP = [2808,2353,3006,3002,1712,2880,2181,2335,2171,2857]
KevinDurant_MP = [1255,1255,2768,2885,3239,3038,2546,3119,3122,913]
DerrickRose_MP = [1168,1168,1168,3000,2871,3026,1375,0,311,1530]
DwayneWade_MP = [2892,1931,1954,3048,2792,2823,1625,2391,1775,1971]
#Matrix
MinutesPlayed = np.array([KobeBryant_MP, JoeJohnson_MP, LeBronJames_MP, CarmeloAnthony_MP, DwightHoward_MP, ChrisBosh_MP, ChrisPaul_MP, KevinDurant_MP, DerrickRose_MP, DwayneWade_MP])
print("Minutes Played")
data3 = {'KobeBryant': KobeBryant_MP,
        'JoeJohnson': JoeJohnson_MP,
        'LeBronJames': LeBronJames_MP,
        'CarmeloAnthony': CarmeloAnthony_MP,
        'DwightHoward': DwightHoward_MP,
        'ChrisBosh': ChrisBosh_MP,
        'ChrisPaul': ChrisPaul_MP,
        'KevinDurant': KevinDurant_MP,
        'DerrickRose': DerrickRose_MP,
        'DwayneWade': DwayneWade_MP}
minutes_played = pd.Series(data3)
# print(minutes_played)

#Field Goals
KobeBryant_FG = [978,813,775,800,716,740,574,738,31,266]
JoeJohnson_FG = [632,536,647,620,635,514,423,445,462,446]
LeBronJames_FG = [875,772,794,789,768,758,621,765,767,624]
CarmeloAnthony_FG = [756,691,728,535,688,684,441,669,743,358]
DwightHoward_FG = [468,526,583,560,510,619,416,470,473,251]
ChrisBosh_FG = [549,543,507,615,600,524,393,485,492,343]
ChrisPaul_FG = [407,381,630,631,314,430,425,412,406,568]
KevinDurant_FG = [306,306,587,661,794,711,643,731,849,238]
DerrickRose_FG = [208,208,208,574,672,711,302,0,58,338]
DwayneWade_FG = [699,472,439,854,719,692,416,569,415,509]
#Matrix
FieldGoals  = np.array([KobeBryant_FG, JoeJohnson_FG, LeBronJames_FG, CarmeloAnthony_FG, DwightHoward_FG, ChrisBosh_FG, ChrisPaul_FG, KevinDurant_FG, DerrickRose_FG, DwayneWade_FG])
print("Field Goals")
data4 = {'KobeBryant': KobeBryant_FG,
        'JoeJohnson': JoeJohnson_FG,
        'LeBronJames': LeBronJames_FG,
        'CarmeloAnthony': CarmeloAnthony_FG,
        'DwightHoward': DwightHoward_FG,
        'ChrisBosh': ChrisBosh_FG,
        'ChrisPaul': ChrisPaul_FG,
        'KevinDurant': KevinDurant_FG,
        'DerrickRose': DerrickRose_FG,
        'DwayneWade': DwayneWade_FG}
field_goals = pd.Series(data4)
# print(field_goals)

#Field Goal Attempts
KobeBryant_FGA = [2173,1757,1690,1712,1569,1639,1336,1595,73,713]
JoeJohnson_FGA = [1395,1139,1497,1420,1386,1161,931,1052,1018,1025]
LeBronJames_FGA = [1823,1621,1642,1613,1528,1485,1169,1354,1353,1279]
CarmeloAnthony_FGA = [1572,1453,1481,1207,1502,1503,1025,1489,1643,806]
DwightHoward_FGA = [881,873,974,979,834,1044,726,813,800,423]
ChrisBosh_FGA = [1087,1094,1027,1263,1158,1056,807,907,953,745]
ChrisPaul_FGA = [947,871,1291,1255,637,928,890,856,870,1170]
KevinDurant_FGA = [647,647,1366,1390,1668,1538,1297,1433,1688,467]
DerrickRose_FGA = [436,436,436,1208,1373,1597,695,0,164,835]
DwayneWade_FGA = [1413,962,937,1739,1511,1384,837,1093,761,1084]
#Matrix
FieldGoalAttempts = np.array([KobeBryant_FGA, JoeJohnson_FGA, LeBronJames_FGA, CarmeloAnthony_FGA, DwightHoward_FGA, ChrisBosh_FGA, ChrisPaul_FGA, KevinDurant_FGA, DerrickRose_FGA, DwayneWade_FGA])
print("Field Goal Attempts")
data5 = {'KobeBryant': KobeBryant_FGA,
        'JoeJohnson': JoeJohnson_FGA,
        'LeBronJames': LeBronJames_FGA,
        'CarmeloAnthony': CarmeloAnthony_FGA,
        'DwightHoward': DwightHoward_FGA,
        'ChrisBosh': ChrisBosh_FGA,
        'ChrisPaul': ChrisPaul_FGA,
        'KevinDurant': KevinDurant_FGA,
        'DerrickRose': DerrickRose_FGA,
        'DwayneWade': DwayneWade_FGA}
field_goal_attempts = pd.Series(data5)
# print(field_goal_attempts)
#Points
KobeBryant_PTS = [2832,2430,2323,2201,1970,2078,1616,2133,83,782]
JoeJohnson_PTS = [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
LeBronJames_PTS = [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
CarmeloAnthony_PTS = [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
DwightHoward_PTS = [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
ChrisBosh_PTS = [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
ChrisPaul_PTS = [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
KevinDurant_PTS = [903,903,1624,1871,2472,2161,1850,2280,2593,686]
DerrickRose_PTS = [597,597,597,1361,1619,2026,852,0,159,904]
DwayneWade_PTS = [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]
#Matrix
Points = np.array([KobeBryant_PTS, JoeJohnson_PTS, LeBronJames_PTS, CarmeloAnthony_PTS, DwightHoward_PTS, ChrisBosh_PTS, ChrisPaul_PTS, KevinDurant_PTS, DerrickRose_PTS, DwayneWade_PTS])             
print("Points")
data6 = {'KobeBryant': KobeBryant_PTS,
        'JoeJohnson': JoeJohnson_PTS,
        'LeBronJames': LeBronJames_PTS,
        'CarmeloAnthony': CarmeloAnthony_PTS,
        'DwightHoward': DwightHoward_PTS,
        'ChrisBosh': ChrisBosh_PTS,
        'ChrisPaul': ChrisPaul_PTS,
        'KevinDurant': KevinDurant_PTS,
        'DerrickRose': DerrickRose_PTS,
        'DwayneWade': DwayneWade_PTS}
goals = pd.Series(data6)
# print(goals)  salary, games, minutes_played, field_goals, field_goal_attempts, goals

data = pd.DataFrame({"salary":salary, "games":games, "minutes_played":minutes_played, "field_goals":field_goals, "field_goal_attempts":field_goal_attempts, "goals": goals})
data
# Out:
# games
# Minutes Played
# Field Goals
# Field Goal Attempts
# Points
#                                                            salary  \
# KobeBryant      [15946875, 17718750, 19490625, 21262500, 23034...
# JoeJohnson      [12000000, 12744189, 13488377, 14232567, 14976...
# LeBronJames     [4621800, 5828090, 13041250, 14410581, 1577991...
# CarmeloAnthony  [3713640, 4694041, 13041250, 14410581, 1577991...
# DwightHoward    [4493160, 4806720, 6061274, 13758000, 15202590...
# ChrisBosh       [3348000, 4235220, 12455000, 14410581, 1577991...
# ChrisPaul       [3144240, 3380160, 3615960, 4574189, 13520500,...
# KevinDurant     [0, 0, 4171200, 4484040, 4796880, 6053663, 155...
# DerrickRose     [0, 0, 0, 4822800, 5184480, 5546160, 6993708, ...
# DwayneWade      [3031920, 3841443, 13041250, 14410581, 1577991...
#
#                                                    games  \
# KobeBryant       [80, 77, 82, 82, 73, 82, 58, 78, 6, 35]
# ...

# %%
import numpy as np
import pandas as pd

#Seasons
Seasons = ["2005","2006","2007","2008","2009","2010","2011","2012","2013","2014"]
Sdict = {"2005":0,"2006":1,"2007":2,"2008":3,"2009":4,"2010":5,"2011":6,"2012":7,"2013":8,"2014":9}

#Players
Players = ["KobeBryant","JoeJohnson","LeBronJames","CarmeloAnthony","DwightHoward","ChrisBosh","ChrisPaul","KevinDurant","DerrickRose","DwayneWade"]
Pdict = {"KobeBryant":0,"JoeJohnson":1,"LeBronJames":2,"CarmeloAnthony":3,"DwightHoward":4,"ChrisBosh":5,"ChrisPaul":6,"KevinDurant":7,"DerrickRose":8,"DwayneWade":9}

#Salaries
KobeBryant_Salary = [15946875,17718750,19490625,21262500,23034375,24806250,25244493,27849149,30453805,23500000]
JoeJohnson_Salary = [12000000,12744189,13488377,14232567,14976754,16324500,18038573,19752645,21466718,23180790]
LeBronJames_Salary = [4621800,5828090,13041250,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
CarmeloAnthony_Salary = [3713640,4694041,13041250,14410581,15779912,17149243,18518574,19450000,22407474,22458000]
DwightHoward_Salary = [4493160,4806720,6061274,13758000,15202590,16647180,18091770,19536360,20513178,21436271]
ChrisBosh_Salary = [3348000,4235220,12455000,14410581,15779912,14500000,16022500,17545000,19067500,20644400]
ChrisPaul_Salary = [3144240,3380160,3615960,4574189,13520500,14940153,16359805,17779458,18668431,20068563]
KevinDurant_Salary = [0,0,4171200,4484040,4796880,6053663,15506632,16669630,17832627,18995624]
DerrickRose_Salary = [0,0,0,4822800,5184480,5546160,6993708,16402500,17632688,18862875]
DwayneWade_Salary = [3031920,3841443,13041250,14410581,15779912,14200000,15691000,17182000,18673000,15000000]
#Matrix
Salary = np.array([KobeBryant_Salary, JoeJohnson_Salary, LeBronJames_Salary, CarmeloAnthony_Salary, DwightHoward_Salary, ChrisBosh_Salary, ChrisPaul_Salary, KevinDurant_Salary, DerrickRose_Salary, DwayneWade_Salary])

# series
# KobeBryant_Salary_Series = pd.Series(KobeBryant_Salary, index = Seasons)
# JoeJohnson_Salary_Series = pd.Series(JoeJohnson_Salary)
# LeBronJames_Salary_Series = pd.Series(LeBronJames_Salary)
# CarmeloAnthony_Salary_Series = pd.Series(CarmeloAnthony_Salary)
# DwightHoward_Salary_Series = pd.Series(DwightHoward_Salary)
# ChrisBosh_Salary_Series = pd.Series(ChrisBosh_Salary)
# ChrisPaul_Salary_Series = pd.Series(ChrisPaul_Salary)
# KevinDurant_Salary_Series = pd.Series(KevinDurant_Salary)
# DerrickRose_Salary_Series = pd.Series(DerrickRose_Salary)
# DwayneWade_Salary_Series = pd.Series(DwayneWade_Salary)

# data1 = {'KobeBryant': KobeBryant_Salary_Series,
#         'JoeJohnson': JoeJohnson_Salary_Series,
#         'LeBronJames': LeBronJames_Salary_Series,
#         'CarmeloAnthony': CarmeloAnthony_Salary_Series,
#         'DwightHoward': DwightHoward_Salary_Series,
#         'ChrisBosh': ChrisBosh_Salary_Series,
#         'ChrisPaul': ChrisPaul_Salary_Series,
#         'KevinDurant': KevinDurant_Salary_Series,
#         'DerrickRose': DerrickRose_Salary_Series,
#         'DwayneWade': DwayneWade_Salary_Series}
# salary = pd.Series(data1)
print("salary--------------------------")
salary_df = pd.DataFrame(Salary, index=Players, columns=Seasons)

print(salary_df)

#Games 
KobeBryant_G = [80,77,82,82,73,82,58,78,6,35]
JoeJohnson_G = [82,57,82,79,76,72,60,72,79,80]
LeBronJames_G = [79,78,75,81,76,79,62,76,77,69]
CarmeloAnthony_G = [80,65,77,66,69,77,55,67,77,40]
DwightHoward_G = [82,82,82,79,82,78,54,76,71,41]
ChrisBosh_G = [70,69,67,77,70,77,57,74,79,44]
ChrisPaul_G = [78,64,80,78,45,80,60,70,62,82]
KevinDurant_G = [35,35,80,74,82,78,66,81,81,27]
DerrickRose_G = [40,40,40,81,78,81,39,0,10,51]
DwayneWade_G = [75,51,51,79,77,76,49,69,54,62]
#Matrix
Games = np.array([KobeBryant_G, JoeJohnson_G, LeBronJames_G, CarmeloAnthony_G, DwightHoward_G, ChrisBosh_G, ChrisPaul_G, KevinDurant_G, DerrickRose_G, DwayneWade_G])

# series
# KobeBryant_G_Series = pd.Series(KobeBryant_G)
# JoeJohnson_G_Series = pd.Series(JoeJohnson_G)
# LeBronJames_G_Series = pd.Series(LeBronJames_G)
# CarmeloAnthony_G_Series = pd.Series(CarmeloAnthony_G)
# DwightHoward_G_Series = pd.Series(DwightHoward_G)
# ChrisBosh_G_Series = pd.Series(ChrisBosh_G)
# ChrisPaul_G_Series = pd.Series(ChrisPaul_G)
# KevinDurant_G_Series = pd.Series(KevinDurant_G)
# DerrickRose_G_Series = pd.Series(DerrickRose_G)
# DwayneWade_G_Series = pd.Series(DwayneWade_G)

# data2 = {'KobeBryant': KobeBryant_G_Series,
#         'JoeJohnson': JoeJohnson_G_Series,
#         'LeBronJames': LeBronJames_G_Series,
#         'CarmeloAnthony': CarmeloAnthony_G_Series,
#         'DwightHoward': DwightHoward_G_Series,
#         'ChrisBosh': ChrisBosh_G_Series,
#         'ChrisPaul': ChrisPaul_G_Series,
#         'KevinDurant': KevinDurant_G_Series,
#         'DerrickRose': DerrickRose_G_Series,
#         'DwayneWade': DwayneWade_G_Series}
# games = pd.Series(data2)
print("games------------------------")

games_df = pd.DataFrame(Games, index=Players, columns=Seasons)

print(games_df)

#Minutes Played
KobeBryant_MP = [3277,3140,3192,2960,2835,2779,2232,3013,177,1207]
JoeJohnson_MP = [3340,2359,3343,3124,2886,2554,2127,2642,2575,2791]
LeBronJames_MP = [3361,3190,3027,3054,2966,3063,2326,2877,2902,2493]
CarmeloAnthony_MP = [2941,2486,2806,2277,2634,2751,1876,2482,2982,1428]
DwightHoward_MP = [3021,3023,3088,2821,2843,2935,2070,2722,2396,1223]
ChrisBosh_MP = [2751,2658,2425,2928,2526,2795,2007,2454,2531,1556]
ChrisPaul_MP = [2808,2353,3006,3002,1712,2880,2181,2335,2171,2857]
KevinDurant_MP = [1255,1255,2768,2885,3239,3038,2546,3119,3122,913]
DerrickRose_MP = [1168,1168,1168,3000,2871,3026,1375,0,311,1530]
DwayneWade_MP = [2892,1931,1954,3048,2792,2823,1625,2391,1775,1971]
#Matrix
MinutesPlayed = np.array([KobeBryant_MP, JoeJohnson_MP, LeBronJames_MP, CarmeloAnthony_MP, DwightHoward_MP, ChrisBosh_MP, ChrisPaul_MP, KevinDurant_MP, DerrickRose_MP, DwayneWade_MP])

# series
# KobeBryant_MP_Series = pd.Series(KobeBryant_MP)
# JoeJohnson_MP_Series = pd.Series(JoeJohnson_MP)
# LeBronJames_MP_Series = pd.Series(LeBronJames_MP)
# CarmeloAnthony_MP_Series = pd.Series(CarmeloAnthony_MP)
# DwightHoward_MP_Series = pd.Series(DwightHoward_MP)
# ChrisBosh_MP_Series = pd.Series(ChrisBosh_MP)
# ChrisPaul_MP_Series = pd.Series(ChrisPaul_MP)
# KevinDurant_MP_Series = pd.Series(KevinDurant_MP)
# DerrickRose_MP_Series = pd.Series(DerrickRose_MP)
# DwayneWade_MP_Series = pd.Series(DwayneWade_MP)

# data3 = {'KobeBryant': KobeBryant_MP_Series,
#         'JoeJohnson': JoeJohnson_MP_Series,
#         'LeBronJames': LeBronJames_MP_Series,
#         'CarmeloAnthony': CarmeloAnthony_MP_Series,
#         'DwightHoward': DwightHoward_MP_Series,
#         'ChrisBosh': ChrisBosh_MP_Series,
#         'ChrisPaul': ChrisPaul_MP_Series,
#         'KevinDurant': KevinDurant_MP_Series,
#         'DerrickRose': DerrickRose_MP_Series,
#         'DwayneWade': DwayneWade_MP_Series}
# minutes_played = pd.Series(data3)
print("minutes played-------------------")

minutes_played_df = pd.DataFrame(MinutesPlayed, index=Players, columns=Seasons)

print(minutes_played_df)

#Field Goals
KobeBryant_FG = [978,813,775,800,716,740,574,738,31,266]
JoeJohnson_FG = [632,536,647,620,635,514,423,445,462,446]
LeBronJames_FG = [875,772,794,789,768,758,621,765,767,624]
CarmeloAnthony_FG = [756,691,728,535,688,684,441,669,743,358]
DwightHoward_FG = [468,526,583,560,510,619,416,470,473,251]
ChrisBosh_FG = [549,543,507,615,600,524,393,485,492,343]
ChrisPaul_FG = [407,381,630,631,314,430,425,412,406,568]
KevinDurant_FG = [306,306,587,661,794,711,643,731,849,238]
DerrickRose_FG = [208,208,208,574,672,711,302,0,58,338]
DwayneWade_FG = [699,472,439,854,719,692,416,569,415,509]
#Matrix
FieldGoals  = np.array([KobeBryant_FG, JoeJohnson_FG, LeBronJames_FG, CarmeloAnthony_FG, DwightHoward_FG, ChrisBosh_FG, ChrisPaul_FG, KevinDurant_FG, DerrickRose_FG, DwayneWade_FG])

# series

# KobeBryant_FG_Series = pd.Series(KobeBryant_FG)
# JoeJohnson_FG_Series = pd.Series(JoeJohnson_FG)
# LeBronJames_FG_Series = pd.Series(LeBronJames_FG)
# CarmeloAnthony_FG_Series = pd.Series(CarmeloAnthony_FG)
# DwightHoward_FG_Series = pd.Series(DwightHoward_FG)
# ChrisBosh_FG_Series = pd.Series(ChrisBosh_FG)
# ChrisPaul_FG_Series = pd.Series(ChrisPaul_FG)
# KevinDurant_FG_Series = pd.Series(KevinDurant_FG)
# DerrickRose_FG_Series = pd.Series(DerrickRose_FG)
# DwayneWade_FG_Series = pd.Series(DwayneWade_FG)

# data4 = {'KobeBryant': KobeBryant_FG_Series,
#         'JoeJohnson': JoeJohnson_FG_Series,
#         'LeBronJames': LeBronJames_FG_Series,
#         'CarmeloAnthony': CarmeloAnthony_FG_Series,
#         'DwightHoward': DwightHoward_FG_Series,
#         'ChrisBosh': ChrisBosh_FG_Series,
#         'ChrisPaul': ChrisPaul_FG_Series,
#         'KevinDurant': KevinDurant_FG_Series,
#         'DerrickRose': DerrickRose_FG_Series,
#         'DwayneWade': DwayneWade_FG_Series}
# field_goals = pd.Series(data4)
# print(field_goals)

print("field goals-----------------------")

field_goals_df = pd.DataFrame(FieldGoals, index=Players, columns=Seasons)

print(field_goals_df)

#Field Goal Attempts
KobeBryant_FGA = [2173,1757,1690,1712,1569,1639,1336,1595,73,713]
JoeJohnson_FGA = [1395,1139,1497,1420,1386,1161,931,1052,1018,1025]
LeBronJames_FGA = [1823,1621,1642,1613,1528,1485,1169,1354,1353,1279]
CarmeloAnthony_FGA = [1572,1453,1481,1207,1502,1503,1025,1489,1643,806]
DwightHoward_FGA = [881,873,974,979,834,1044,726,813,800,423]
ChrisBosh_FGA = [1087,1094,1027,1263,1158,1056,807,907,953,745]
ChrisPaul_FGA = [947,871,1291,1255,637,928,890,856,870,1170]
KevinDurant_FGA = [647,647,1366,1390,1668,1538,1297,1433,1688,467]
DerrickRose_FGA = [436,436,436,1208,1373,1597,695,0,164,835]
DwayneWade_FGA = [1413,962,937,1739,1511,1384,837,1093,761,1084]
#Matrix
FieldGoalAttempts = np.array([KobeBryant_FGA, JoeJohnson_FGA, LeBronJames_FGA, CarmeloAnthony_FGA, DwightHoward_FGA, ChrisBosh_FGA, ChrisPaul_FGA, KevinDurant_FGA, DerrickRose_FGA, DwayneWade_FGA])

# series
# KobeBryant_FGA_Series = pd.Series(KobeBryant_FGA)
# JoeJohnson_FGA_Series = pd.Series(JoeJohnson_FGA)
# LeBronJames_FGA_Series = pd.Series(LeBronJames_FGA)
# CarmeloAnthony_FGA_Series = pd.Series(CarmeloAnthony_FGA)
# DwightHoward_FGA_Series = pd.Series(DwightHoward_FGA)
# ChrisBosh_FGA_Series = pd.Series(ChrisBosh_FGA)
# ChrisPaul_FGA_Series = pd.Series(ChrisPaul_FGA)
# KevinDurant_FGA_Series = pd.Series(KevinDurant_FGA)
# DerrickRose_FGA_Series = pd.Series(DerrickRose_FGA)
# DwayneWade_FGA_Series = pd.Series(DwayneWade_FGA)

# data5 = {'KobeBryant': KobeBryant_FGA_Series,
#         'JoeJohnson': JoeJohnson_FGA_Series,
#         'LeBronJames': LeBronJames_FGA_Series,
#         'CarmeloAnthony': CarmeloAnthony_FGA_Series,
#         'DwightHoward': DwightHoward_FGA_Series,
#         'ChrisBosh': ChrisBosh_FGA_Series,
#         'ChrisPaul': ChrisPaul_FGA_Series,
#         'KevinDurant': KevinDurant_FGA_Series,
#         'DerrickRose': DerrickRose_FGA_Series,
#         'DwayneWade': DwayneWade_FGA_Series}
# field_goal_attempts = pd.Series(data5)
# print(field_goal_attempts)

print("Field Goal Attempts-------------------")

field_goal_attempts_df = pd.DataFrame(FieldGoalAttempts, index=Players, columns=Seasons)

print(field_goal_attempts_df)

#Points
KobeBryant_PTS = [2832,2430,2323,2201,1970,2078,1616,2133,83,782]
JoeJohnson_PTS = [1653,1426,1779,1688,1619,1312,1129,1170,1245,1154]
LeBronJames_PTS = [2478,2132,2250,2304,2258,2111,1683,2036,2089,1743]
CarmeloAnthony_PTS = [2122,1881,1978,1504,1943,1970,1245,1920,2112,966]
DwightHoward_PTS = [1292,1443,1695,1624,1503,1784,1113,1296,1297,646]
ChrisBosh_PTS = [1572,1561,1496,1746,1678,1438,1025,1232,1281,928]
ChrisPaul_PTS = [1258,1104,1684,1781,841,1268,1189,1186,1185,1564]
KevinDurant_PTS = [903,903,1624,1871,2472,2161,1850,2280,2593,686]
DerrickRose_PTS = [597,597,597,1361,1619,2026,852,0,159,904]
DwayneWade_PTS = [2040,1397,1254,2386,2045,1941,1082,1463,1028,1331]
#Matrix
Points = np.array([KobeBryant_PTS, JoeJohnson_PTS, LeBronJames_PTS, CarmeloAnthony_PTS, DwightHoward_PTS, ChrisBosh_PTS, ChrisPaul_PTS, KevinDurant_PTS, DerrickRose_PTS, DwayneWade_PTS])             

# series
# KobeBryant_PTS_Series = pd.Series(KobeBryant_PTS)
# JoeJohnson_PTS_Series = pd.Series(JoeJohnson_PTS)
# LeBronJames_PTS_Series = pd.Series(LeBronJames_PTS)
# CarmeloAnthony_PTS_Series = pd.Series(CarmeloAnthony_PTS)
# DwightHoward_PTS_Series = pd.Series(DwightHoward_PTS)
# ChrisBosh_PTS_Series = pd.Series(ChrisBosh_PTS)
# ChrisPaul_PTS_Series = pd.Series(ChrisPaul_PTS)
# KevinDurant_PTS_Series = pd.Series(KevinDurant_PTS)
# DerrickRose_PTS_Series = pd.Series(DerrickRose_PTS)
# DwayneWade_PTS_Series = pd.Series(DwayneWade_PTS)

# data6 = {'KobeBryant': KobeBryant_PTS_Series,
#         'JoeJohnson': JoeJohnson_PTS_Series,
#         'LeBronJames': LeBronJames_PTS_Series,
#         'CarmeloAnthony': CarmeloAnthony_PTS_Series,
#         'DwightHoward': DwightHoward_PTS_Series,
#         'ChrisBosh': ChrisBosh_PTS_Series,
#         'ChrisPaul': ChrisPaul_PTS_Series,
#         'KevinDurant': KevinDurant_PTS_Series,
#         'DerrickRose': DerrickRose_PTS_Series,
#         'DwayneWade': DwayneWade_PTS_Series}
# goals = pd.Series(data6)
# print(goals)

print("Points-------------------")

points_df = pd.DataFrame(Points, index=Players, columns=Seasons)

print(points_df)

# data = pd.DataFrame({"salary":salary, "games":games, "minutes_played":minutes_played, "field_goals":field_goals, "field_goal_attempts":field_goal_attempts, "goals": goals})
# data
# Out:
# salary--------------------------
#                     2005      2006      2007      2008      2009      2010  \
# KobeBryant      15946875  17718750  19490625  21262500  23034375  24806250
# JoeJohnson      12000000  12744189  13488377  14232567  14976754  16324500
# LeBronJames      4621800   5828090  13041250  14410581  15779912  14500000
# CarmeloAnthony   3713640   4694041  13041250  14410581  15779912  17149243
# DwightHoward     4493160   4806720   6061274  13758000  15202590  16647180
# ChrisBosh        3348000   4235220  12455000  14410581  15779912  14500000
# ChrisPaul        3144240   3380160   3615960   4574189  13520500  14940153
# KevinDurant            0         0   4171200   4484040   4796880   6053663
# DerrickRose            0         0         0   4822800   5184480   5546160
# DwayneWade       3031920   3841443  13041250  14410581  15779912  14200000
#
#                     2011      2012      2013      2014
# ...
